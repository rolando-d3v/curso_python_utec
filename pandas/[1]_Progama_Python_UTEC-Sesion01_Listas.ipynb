# %% [markdown]
# ## [1] Ejemplos de resultados en Python (listas)

# %% [markdown]
# ### [1.1] De expresiones regulares

# %%
import re

# %%
texto = "Mi correo personal es david.allendeq@gmail.com y mi correo corporativo es david.allende@misdsolutions.com"

# %%
print(texto)
# Out:
# Mi correo personal es david.allendeq@gmail.com y mi correo corporativo es david.allende@misdsolutions.com

# %%
correos = re.findall(r'\S+@\S+',texto)

# %%
print(correos)
# Out:
# ['david.allendeq@gmail.com', 'david.allende@misdsolutions.com']

# %%
type(correos)
# Out:
# list

# %%
import pandas as pd

# %%
df = pd.read_csv("clientes.csv" ,sep=';')
print(df)
# Out:
#     ID  EDAD  INGRESOS RIESGO  LINEA_TC
# 0  123    36      1348      A     49924
# 1  234    52      9479      A     28454
# 2  345    60      7511      B     14250
# 3  456    40      7992      C     32064
# 4  567    58      2675      C      1485
# 5  678    47      7086      D     29157
# 6  789    31      4704      E     14945
# 7  999    42      6245      E      8798

# %%
variables = df.columns.to_list()
variables
# Out:
# ['ID', 'EDAD', 'INGRESOS', 'RIESGO', 'LINEA_TC']

# %%
nombre = "Rolando"
apellido_paterno = "Mamani"
apellido_materno = "Flores"
profesion = "Ingeniero de sistemas"
edad = 30
centro_laboral = "Mindef"
year_experiencia = 12

# %%
info_personal = [nombre, apellido_paterno, apellido_materno, profesion, edad, centro_laboral, year_experiencia]

# %%
type(info_personal)
print(info_personal)
# Out:
# ['Rolando', 'Mamani', 'Flores', 'Ingeniero de sistemas', 30, 'Mindef', 12]

# %% [markdown]
# Acceder a una lista

# %%
lugares_favoritos = ["Paris", "Londres", "Nueva York", "Tokyo", "Barcelona"]

print(f"Mis lugares favoritos son: {lugares_favoritos}")
# Out:
# Mis lugares favoritos son: ['Paris', 'Londres', 'Nueva York', 'Tokyo', 'Barcelona']

# %%
marcas = []
for i in range(5):
    ingreso_marca = input(f"Ingrese una marca#{i+1}: ").capitalize()
    marcas.append(ingreso_marca)

print(f"Mis marcas favoritas son: {marcas}")

# %%
info = {
    "nombre": "Rolando",
    "apellido_paterno": "Mamani",
    "profesion": "Ingeniero de sistemas",
    "edad": 30,
    "centro_laboral": "Mindef",
    "year_experiencia": 12
}

# Cambiar el centro laboral
info["centro_laboral"] = "Google"
# info[5] = "Google"

print(info)
# Out:
# {'nombre': 'Rolando', 'apellido_paterno': 'Mamani', 'profesion': 'Ingeniero de sistemas', 'edad': 30, 'centro_laboral': 'Mindef', 'year_experiencia': 12, 5: 'Google'}
