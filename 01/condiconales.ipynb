# %% [markdown]
# <a href="https://colab.research.google.com/github/rolando-d3v/curso_python_utec/blob/main/01/condiconales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Cargar los datos
df = pd.read_csv("casas.csv")

# Variables
X = df[["metros_cuadrados"]]  # variable independiente
y = df["precio"]               # variable dependiente

# Crear el modelo
modelo = LinearRegression()
modelo.fit(X, y)

# Predicciones
y_pred = modelo.predict(X)

# Mostrar resultados
plt.scatter(X, y, color='blue', label='Datos reales')
plt.plot(X, y_pred, color='red', label='Línea de regresión')
plt.xlabel("Metros cuadrados")
plt.ylabel("Precio (S/)")
plt.title("Regresión lineal: Precio vs Metros cuadrados")
plt.legend()
plt.show()

# Coeficientes
print("Pendiente (b):", modelo.coef_[0])
print("Intercepto (a):", modelo.intercept_)

# %% [markdown]
# ffgn
