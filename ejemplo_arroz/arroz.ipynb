# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar el archivo csv
dataF = pd.read_csv("./data_arroz.csv" , encoding="latin-1")
# dataF = pd.read_csv("./data_arroz.csv", sep=';', encoding='utf-8')

# Ver las primeras filas para confirmar que se cargó bien
print(dataF.head(5))
# print(dataF.columns)
# Out:
#                            Sku  Semana  Precio  Demanda
# 0  ARROZ EXTRA  X 5 KG COSTEÑO  201709    18.9     2468
# 1  ARROZ EXTRA  X 5 KG COSTEÑO  201710    19.2     1746
# 2  ARROZ EXTRA  X 5 KG COSTEÑO  201711    20.7     3941
# 3  ARROZ EXTRA  X 5 KG COSTEÑO  201712    18.4     4244
# 4  ARROZ EXTRA  X 5 KG COSTEÑO  201713    20.4    11699

# %%
# Convertir el DataFrame a un array
array_arroz = dataF.values
print(f"El array tiene: {array_arroz}")
# Out:
# El array tiene: [['ARROZ EXTRA  X 5 KG COSTEÑO' 201709 18.9 2468]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201710 19.2 1746]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201711 20.7 3941]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201712 18.4 4244]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201713 20.4 11699]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201714 24.0 1746]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201715 19.6 3941]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201716 18.9 4244]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201717 18.5 9231]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201718 18.9 10703]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201719 19.1 6751]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201720 17.3 11648]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201721 17.4 10219]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201722 18.1 13600]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201723 18.3 11005]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201724 17.8 9112]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201725 15.6 28216]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201726 17.5 14062]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201727 19.2 9304]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201728 19.0 9367]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201729 19.2 8284]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201730 14.9 31372]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201731 16.8 3487]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201732 19.2 4859]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201733 18.9 7503]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201734 16.3 24464]
#  ['ARROZ EXTRA  X 5 KG COSTEÑO' 201735 17.4 13449]]

# %%
# dimensiones del array 2
print("el array tiene  dimensiones: ", array_arroz.ndim)

# el tamaño de cada dimension primera dimension filas 27 , segunda dimension columnas 4
print("el tamaño de cada dimension: ", array_arroz.shape)

# la cantidad de registros del arreglo
print("la cantidad de registros del arreglo es: ", array_arroz.size)
# Out:
# el array tiene  dimensiones:  2
# el tamaño de cada dimension:  (27, 4)
# la cantidad de registros del arreglo es:  108

# %%
# seleccionar solo las columnas precio y demanda
array_arroz_modificado = array_arroz[:,2:]

print(f"El array tiene: {array_arroz_modificado}")

# dimensiones del array 2
print("el array tiene  dimensiones: ", array_arroz_modificado.ndim)

# el tamaño de cada dimension primera dimension filas 27 , segunda dimension columnas 4
print("el tamaño de cada dimension: ", array_arroz_modificado.shape)

# la cantidad de registros del arreglo
print("la cantidad de registros del arreglo es: ", array_arroz_modificado.size)
# Out:
# El array tiene: [[18.9 2468]
#  [19.2 1746]
#  [20.7 3941]
#  [18.4 4244]
#  [20.4 11699]
#  [24.0 1746]
#  [19.6 3941]
#  [18.9 4244]
#  [18.5 9231]
#  [18.9 10703]
#  [19.1 6751]
#  [17.3 11648]
#  [17.4 10219]
#  [18.1 13600]
#  [18.3 11005]
#  [17.8 9112]
#  [15.6 28216]
#  [17.5 14062]
#  [19.2 9304]
#  [19.0 9367]
#  [19.2 8284]
#  [14.9 31372]
#  [16.8 3487]
#  [19.2 4859]
#  [18.9 7503]
#  [16.3 24464]
#  [17.4 13449]]
# el array tiene  dimensiones:  2
# el tamaño de cada dimension:  (27, 2)
# la cantidad de registros del arreglo es:  54
