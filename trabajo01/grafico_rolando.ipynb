# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo xlsx
df = pd.read_excel("./data_Leads enero-julio 2025.xlsx")

# Ver las primeras filas para confirmar que se cargó bien
# print(df.head())
print(df.columns)
# Out:
# Index(['N°', 'Fecha Creación', 'Usuario Creador', 'Tipo Persona', 'Nombres',
#        'Tipo Documento', 'Nº Documento', 'Genero', 'Estado Civil',
#        'Medio De Captacion', 'Canal De Entrada', 'Nivel De Interes', 'Email',
#        'Telefono Principal', 'Celulares', 'Edad', 'Nacionalidad', 'Pais',
#        'Departamento', 'Provincia', 'Distrito', 'Domicilio',
#        'Proyectos Relacionados', 'Usuarios Relacionados',
#        'Número Interacciones', 'Número Visitas', 'Fecha Última Interacción',
#        'Última Interacción', 'Descripción Interacción', 'Observaciones',
#        'Proceso De Captación', 'Autorización uso datos', 'Apto',
#        'Autorización Publicidad', 'Tipo de Financiamiento',
#        'Fecha de Primera Interacción Manual'],
#       dtype='object')
